# %%
import matplotlib.pyplot as plt
import numpy as np

import matplotlib.cm as cm
color_map  = cm.get_cmap('tab20c')

# %%
Am_concate = {}
Am_single = {}

# %%
#p=150
Am_con_list = [
"7.58115658326798 3.62480713301223",
"5.8713924156741 3.27182688859917",
"4.39188121294855 2.21282230974177",
"4.03098993836194 2.11965469493617",
"3.89574391854943 1.48602435742893",
"2.6715575403858 1.3934608008171",
"2.99837969562232 2.08385873040034",
"1.53123502750864 0.838040293004443",
"1.28864302171441 0.70926209135135",
"0.668932556020691 0.355461326144518",
"0.764896044824598 0.538669838400117"
]

Am_temp = np.zeros((len(Am_con_list),2))
for id, item in enumerate(Am_con_list):
    x = item.split(" ")
    Am_temp[id, 0] = float(x[0])
    Am_temp[id, 1] = float(x[1])
Am_concate['p150'] = Am_temp



#p=100
Am_con_list100 = [
"6.97565394050411 3.5306046976479",
"5.44923774440223 2.01363074439264",
"4.51242632595114 1.93757561636217",
"4.19518403892075 2.3431582695874",
"2.99546633377847 1.51925545943297",
"2.96346241356827 1.03665606450421",
"2.44139629306864 1.30114678173496",
"1.78529967362904 0.989061179875264",
"1.14025945895012 0.515604784211165",
"0.838249258517799 0.497294157377223",
"0.914998709409389 0.458015111261749"
]

Am_temp = np.zeros((len(Am_con_list100),2))
for id, item in enumerate(Am_con_list100):
    x = item.split(" ")
    Am_temp[id, 0] = float(x[0])
    Am_temp[id, 1] = float(x[1])
Am_concate['p100'] = Am_temp


#p=50
Am_con_list50 = [
"7.43210688855305 3.72069001981433",
"4.86427481379958 1.47534013268262",
"4.53067773692922 2.07418272435942",
"3.98844913720182 1.44818001561388",
"4.24835488628592 2.16806136828209",
"2.67007736457282 1.49856748848624",
"1.86098544677662 1.18743352630483",
"1.97497602944553 1.29922852246506",
"1.1738181274809 0.72915298363582",
"1.1733440554103 0.572874037292427",
"0.80851401860069 0.527120579045776"
]

Am_temp = np.zeros((len(Am_con_list50),2))
for id, item in enumerate(Am_con_list50):
    x = item.split(" ")
    Am_temp[id, 0] = float(x[0])
    Am_temp[id, 1] = float(x[1])
Am_concate['p50'] = Am_temp

# %%
Am_concate
# Out:
# {'p150': array([[7.58115658, 3.62480713],
#         [5.87139242, 3.27182689],
#         [4.39188121, 2.21282231],
#         [4.03098994, 2.11965469],
#         [3.89574392, 1.48602436],
#         [2.67155754, 1.3934608 ],
#         [2.9983797 , 2.08385873],
#         [1.53123503, 0.83804029],
#         [1.28864302, 0.70926209],
#         [0.66893256, 0.35546133],
#         [0.76489604, 0.53866984]]),
#  'p100': array([[6.97565394, 3.5306047 ],
#         [5.44923774, 2.01363074],
#         [4.51242633, 1.93757562],
#         [4.19518404, 2.34315827],
#         [2.99546633, 1.51925546],
#         [2.96346241, 1.03665606],
#         [2.44139629, 1.30114678],
#         [1.78529967, 0.98906118],
#         [1.14025946, 0.51560478],
#         [0.83824926, 0.49729416],
#         [0.91499871, 0.45801511]]),
#  'p50': array([[7.43210689, 3.72069002],
#         [4.86427481, 1.47534013],
#         [4.53067774, 2.07418272],
#         [3.98844914, 1.44818002],
#         [4.24835489, 2.16806137],
# ...

# %%
#p=150
Am_single_list = [
"7.82871895924105 3.3898943791101",
"5.59556997971841 3.18370634141641",
"4.94830521300539 2.56840231963841",
"4.0309131349463 1.57985650273961",
"3.1003164464345 1.31068646605772",
"3.55090007586351 1.82532722521542",
"3.09012805923666 2.0470063928174",
"1.54875232079936 0.869765069817262",
"1.07383392539381 0.576735819303879",
"0.75145670690242 0.57702362773195",
"0.725692960203099 0.503122033231406",
]

Am_temp = np.zeros((len(Am_single_list),2))
for id, item in enumerate(Am_single_list):
    x = item.split(" ")
    Am_temp[id, 0] = float(x[0])
    Am_temp[id, 1] = float(x[1])
Am_single['p150'] = Am_temp



#p=100
Am_single_list100 = [
"7.19899495951294 3.22223089140495",
"6.29200332877281 2.78222447972603",
"5.34037790946397 2.73022805042285",
"4.24914694807242 2.05945711158253",
"3.6869104898785 1.71782487119679",
"2.69489006834514 1.15629827615812",
"2.61662893694383 1.1070181516364",
"1.53044273098495 1.02481819738252",
"1.24634298251626 0.634052829433927",
"0.941996968595055 0.460691133560638",
"0.95404655477808 0.56932062687224",
]

Am_temp = np.zeros((len(Am_single_list100),2))
for id, item in enumerate(Am_single_list100):
    x = item.split(" ")
    Am_temp[id, 0] = float(x[0])
    Am_temp[id, 1] = float(x[1])
Am_single['p100'] = Am_temp


#p=50
Am_single_list50 = [
"7.40866629032481 3.26973172704509",
"4.69727282260992 1.66214601996256",
"5.86272637442974 2.4657066784169",
"4.28517450452388 1.65433660065763",
"3.89056399337337 1.81158779982998",
"3.03660917254934 1.63499738349582",
"2.07580476945009 1.06568027303242",
"1.87905160733446 1.12380076343302",
"1.20454553556224 0.691585600480897",
"1.07847478295324 0.407758821531265",
"0.773189459284527 0.392026635475854",
]

Am_temp = np.zeros((len(Am_single_list50),2))
for id, item in enumerate(Am_single_list50):
    x = item.split(" ")
    Am_temp[id, 0] = float(x[0])
    Am_temp[id, 1] = float(x[1])
Am_single['p50'] = Am_temp

# %%
Am_single
# Out:
# {'p150': array([[7.82871896, 3.38989438],
#         [5.59556998, 3.18370634],
#         [4.94830521, 2.56840232],
#         [4.03091313, 1.5798565 ],
#         [3.10031645, 1.31068647],
#         [3.55090008, 1.82532723],
#         [3.09012806, 2.04700639],
#         [1.54875232, 0.86976507],
#         [1.07383393, 0.57673582],
#         [0.75145671, 0.57702363],
#         [0.72569296, 0.50312203]]),
#  'p100': array([[7.19899496, 3.22223089],
#         [6.29200333, 2.78222448],
#         [5.34037791, 2.73022805],
#         [4.24914695, 2.05945711],
#         [3.68691049, 1.71782487],
#         [2.69489007, 1.15629828],
#         [2.61662894, 1.10701815],
#         [1.53044273, 1.0248182 ],
#         [1.24634298, 0.63405283],
#         [0.94199697, 0.46069113],
#         [0.95404655, 0.56932063]]),
#  'p50': array([[7.40866629, 3.26973173],
#         [4.69727282, 1.66214602],
#         [5.86272637, 2.46570668],
#         [4.2851745 , 1.6543366 ],
#         [3.89056399, 1.8115878 ],
# ...

# %%
fig, ax = plt.subplots(1, 3, figsize=(15,5))
N = [100,150,200,300,400,500,1000,2000,5000,10000]
x_label = [(81*np.log10(50)/n) for n in N]

b_mean = []
b_std = []

Am_c_p50 = Am_concate['p50']

ax[0].errorbar(x=x_label, y=Am_c_p50[1::,0], yerr=Am_c_p50[1::,1], fmt='-o', label=r'initialize with $\hat A_m$ (p=50)', color=color_map(0))


Am_s_p50 = Am_concate['p50']

ax[0].errorbar(x=x_label, y=Am_s_p50[1::,0], yerr=Am_s_p50[1::,1], fmt='-o', label=r'initialize with $\hat A_m$ (p=50)', color=color_map(2))


x_label = [(81*np.log10(100)/n) for n in N]

Am_c_p100 = Am_concate['p100']

ax[1].errorbar(x=x_label, y=Am_c_p100[1::,0], yerr=Am_c_p100[1::,1], fmt='-o', label=r'initialize with $\hat A_m$ (p=50)', color=color_map(0))


Am_s_p100 = Am_concate['p100']

ax[1].errorbar(x=x_label, y=Am_s_p100[1::,0], yerr=Am_s_p100[1::,1], fmt='-o', label=r'initialize with $\hat A_m$ (p=50)', color=color_map(2))

x_label = [(81*np.log10(150)/n) for n in N]

Am_c_p150 = Am_concate['p150']

ax[2].errorbar(x=x_label, y=Am_c_p150[1::,0], yerr=Am_c_p150[1::,1], fmt='-o', label=r'initialize with $\hat A_m$ (p=50)', color=color_map(0))


Am_s_p150 = Am_concate['p150']

ax[2].errorbar(x=x_label, y=Am_s_p150[1::,0], yerr=Am_s_p150[1::,1], fmt='-o', label=r'initialize with $\hat A_m$ (p=50)', color=color_map(2))
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ### New Model

# %%
tridiag1 = {}
tridiag2 = {}
tridiag3 = {}

# %%
tridiag1_p50_c = [
"1.82043614184133 1.0216504015502",
"1.35086959823818 0.67075162891559",
"1.74701713576976 0.920129449438846",
"1.34555170121412 1.18494237004633",
"1.11455571119198 0.438264219146245",
"0.919085376850248 0.428515086233345",
"0.806580738506829 0.448754370839104",
"0.72347743999411 0.394674363082984",
"0.419094460733508 0.228226737971612",
"0.308457841900796 0.144706973663061",
"0.245490327425788 0.0642407755801964"
]

tridiag1_p50_i = [
"1.42510022916108 0.65274129423604",
"1.66463656445342 0.846088544336996",
"1.41408943694114 0.931900155743083",
"1.34219479565609 0.573832712640172",
"1.41460538146541 0.737475220266926",
"0.959268627620458 0.718838215775069",
"0.72581298450018 0.40640807549675",
"0.677607345748192 0.297575886045248",
"0.558830509396147 0.204122808096275",
"0.310001910002681 0.127300998865742",
"0.262593477653164 0.0723664506002614"
]

tridiag1_p100_c = [
"1.22424212564541 0.850461716921307",		
"1.63991032147039 0.938209464818926",		
"1.05807256229765 0.769175171483325",		
"1.02885207758304 0.41454060123526",		
"0.974450914446125 0.407596519808843",		
"1.0539128453168 0.722068546123987",		
"0.679578196433777 0.300128819747431",		
"0.690186077756157 0.358719476317705",		
"0.353111869253594 0.129002180082244",		
"0.371908380625436 0.187347495705419",		
"0.237023140270632 0.0677245874323501"		
]

tridiag1_p100_i = [
"1.3109064640119 0.688584870382361",		
"1.55344802221203 0.63947743794304",		
"1.28774465369747 0.744090997964356",		
"1.30478613601369 0.575090200569722",		
"1.37401651043723 0.725957134700182",		
"0.871783161137447 0.518625280322558",		
"0.81298496898005 0.333167616820756",		
"0.705869694070093 0.503371024493567",		
"0.482020390484327 0.250084404038482",		
"0.345198116094268 0.104986186715754",		
"0.217198815318206 0.0586124560782235"		
]

tridiag1_p150_c = [
"1.52104206677743 0.636092525475142",		
"1.30534057953551 0.68618138199347",		
"1.14855563179739 0.455656662980626",		
"1.16422120025713 0.610696964120288",		
"1.04758646230529 0.468102153860032",		
"1.06314141595208 0.647536676690936",		
"1.03911965462291 0.944690124871101",		
"0.614183375462086 0.570755705685537",		
    'tridiag1_p50_c',
    'tridiag1_p50_i',
    'tridiag1_p100_c',
    'tridiag1_p100_i',
    'tridiag1_p150_c',
    'tridiag1_p150_i'
]

tridiag2_list = [
    'tridiag2_p50_c',
    'tridiag2_p50_i',
    'tridiag2_p100_c',
    'tridiag2_p100_i',
    'tridiag2_p150_c',
    'tridiag2_p150_i'
]

tridiag3_list = [
    'tridiag3_p50_c',
    'tridiag3_p50_i',
    'tridiag3_p100_c',
    'tridiag3_p100_i',
    'tridiag3_p150_c',
    'tridiag3_p150_i'
]

# %%
for Am_list in tridiag1_list:

    Am_listli = eval(Am_list)    
    Am_temp = np.zeros((len(Am_listli),2))
    for id, item in enumerate(Am_listli):
        x = item.split(" ")
        Am_temp[id, 0] = float(x[0])
        Am_temp[id, 1] = float(x[1])
    tridiag1[Am_list] = Am_temp


for Am_list in tridiag2_list:

    Am_listli = eval(Am_list)    
    Am_temp = np.zeros((len(Am_listli),2))
    for id, item in enumerate(Am_listli):
        x = item.split(" ")
        Am_temp[id, 0] = float(x[0])
        Am_temp[id, 1] = float(x[1])
    tridiag2[Am_list] = Am_temp


for Am_list in tridiag3_list:

    Am_listli = eval(Am_list)    
    Am_temp = np.zeros((len(Am_listli),2))
    for id, item in enumerate(Am_listli):
        x = item.split(" ")
        Am_temp[id, 0] = float(x[0])
        Am_temp[id, 1] = float(x[1])
    tridiag3[Am_list] = Am_temp

# %%
N50 =  [275, 305, 344, 393, 458, 550, 688, 917, 1376, 2752, 13761]
N100 = [324, 360, 405, 462, 540, 648, 810, 1080, 1620, 3240,16200]
N150 = [352, 391, 440, 503, 587, 705, 881, 1175, 1762, 3525, 17626]

# %%
fig, ax = plt.subplots(1, 3, figsize=(15,5))

N50 =  [275, 305, 344, 393, 458, 550, 688, 917, 1376, 2752, 13761]
N100 = [324, 360, 405, 462, 540, 648, 810, 1080, 1620, 3240,16200]
N150 = [352, 391, 440, 503, 587, 705, 881, 1175, 1762, 3525, 17626]

for i in range(3,4,1):
    xlabel = [(81*np.log10(50)/n) for n in N50]
    name_c  = 'tridiag{}_p50_c'.format(i)
    name_i = 'tridiag{}_p50_i'.format(i)
    test = eval('tridiag'+str(i))

    ax[0].errorbar(x=xlabel[5::], y=test[name_c][5::,0], yerr=test[name_c][5::,1], fmt='-o', color=color_map(0))
    ax[0].errorbar(x=xlabel[5::], y=test[name_i][5::,0], yerr=test[name_i][5::,1], fmt='--x', color=color_map(4))


for i in range(3,4,1):
    xlabel = [(81*np.log10(100)/n) for n in N100]
    name_c  = 'tridiag{}_p100_c'.format(i)
    name_i = 'tridiag{}_p100_i'.format(i)
    test = eval('tridiag'+str(i))

    ax[1].errorbar(x=xlabel[5::], y=test[name_c][5::,0], yerr=test[name_c][5::,1], fmt='-o', color=color_map(0), label="joint nodes (graph 3)")
    ax[1].errorbar(x=xlabel[5::], y=test[name_i][5::,0], yerr=test[name_i][5::,1], fmt='--x', color=color_map(4), label="single node (graph 3)")

    

for i in range(3,4,1):
    xlabel = [(81*np.log10(150)/n) for n in N150]
    name_c  = 'tridiag{}_p150_c'.format(i)
    name_i = 'tridiag{}_p150_i'.format(i)
    test = eval('tridiag'+str(i))

    ax[2].errorbar(x=xlabel[5::], y=test[name_c][5::,0], yerr=test[name_c][5::,1], fmt='-o', color=color_map(0))
    ax[2].errorbar(x=xlabel[5::], y=test[name_i][5::,0], yerr=test[name_i][5::,1], fmt='--x', color=color_map(4))

ax[0].grid()
ax[1].grid()
ax[2].grid()
ax[0].set_title('p=50', fontsize=18)
ax[1].set_title('p=100', fontsize=18)
ax[2].set_title('p=150', fontsize=18)
ax[0].set_ylabel(r'$\sum_{m=1}^M\sigma_A^{-1}\|{A}_m-A_m^\star\|_F^2$', fontsize=18)
ax[1].set_xlabel(r'$\left(k\sum_{m=1}^M k_m\vee k^2 \log p\right)/N$', fontsize=18)

handles, labels = ax[1].get_legend_handles_labels()

fig.legend(handles, labels, ncol=2, bbox_to_anchor=(0.8, -0.0), fontsize=18)

fig.tight_layout()
fig.savefig('tridiag3_sj_compare.pdf', bbox_inches='tight')

# %%
fig, ax = plt.subplots(1, 3, figsize=(15,5))

N50 =  [275, 305, 344, 393, 458, 550, 688, 917, 1376, 2752, 13761]
N100 = [324, 360, 405, 462, 540, 648, 810, 1080, 1620, 3240,16200]
N150 = [352, 391, 440, 503, 587, 705, 881, 1175, 1762, 3525, 17626]

for i in range(3,4,1):
    xlabel = [(81*np.log10(50)/n) for n in N50]
    name_c  = 'tridiag{}_p50_c'.format(i)
    name_i = 'tridiag{}_p50_i'.format(i)
    test = eval('tridiag'+str(i))

    ax[0].errorbar(x=xlabel, y=test[name_c][:,0], yerr=test[name_c][:,1], fmt='-o', color=color_map(0))
    ax[0].errorbar(x=xlabel, y=test[name_i][:,0], yerr=test[name_i][:,1], fmt='--x', color=color_map(4))


for i in range(3,4,1):
    xlabel = [(81*np.log10(100)/n) for n in N100]
    name_c  = 'tridiag{}_p100_c'.format(i)
    name_i = 'tridiag{}_p100_i'.format(i)
    test = eval('tridiag'+str(i))

    ax[1].errorbar(x=xlabel, y=test[name_c][:,0], yerr=test[name_c][:,1], fmt='-o', color=color_map(0), label="joint nodes")
    ax[1].errorbar(x=xlabel, y=test[name_i][:,0], yerr=test[name_i][:,1], fmt='--x', color=color_map(4), label="single node")

    

for i in range(3,4,1):
    xlabel = [(81*np.log10(150)/n) for n in N150]
    name_c  = 'tridiag{}_p150_c'.format(i)
    name_i = 'tridiag{}_p150_i'.format(i)
    test = eval('tridiag'+str(i))

    ax[2].errorbar(x=xlabel, y=test[name_c][:,0], yerr=test[name_c][:,1], fmt='-o', color=color_map(0))
    ax[2].errorbar(x=xlabel, y=test[name_i][:,0], yerr=test[name_i][:,1], fmt='--x', color=color_map(4))

ax[0].grid()
ax[1].grid()
ax[2].grid()
ax[0].set_title('p=50', fontsize=18)
ax[1].set_title('p=100', fontsize=18)
ax[2].set_title('p=150', fontsize=18)
ax[0].set_ylabel(r'$\sum_{m=1}^M\sigma_A^{-1}\|{A}_m-A_m^\star\|_F^2$', fontsize=18)
ax[1].set_xlabel(r'$\left(k\sum_{m=1}^M k_m\vee k^2 \log p\right)/N$', fontsize=18)

handles, labels = ax[1].get_legend_handles_labels()
fig.tight_layout()
fig.legend(handles, labels, ncol=2, bbox_to_anchor=(0.7, -0.0), fontsize=18)
