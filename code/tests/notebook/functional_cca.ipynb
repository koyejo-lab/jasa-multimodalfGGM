# %% [markdown]
# ### Functional CCA
#
# This notebook verifies the concept of the initialization method of the operator A
# (1) input: functional data
# (2) verifies the algorithm in the empirical domain

# %%
library(pracma)
library(matrixcalc)
library(fields)
library(Matrix)
#load source file
src.path <- "../../src"
source(paste(src.path, "DataGenerationProcess", "synth_basis.R", sep="/"))
source(paste(src.path, "DataGenerationProcess", "synth_data.R", sep="/"))
source(paste(src.path, "DataGenerationProcess", "synth_graph.R", sep="/"))
source(paste(src.path, "DataGenerationProcess", "synth_linearop.R", sep="/"))

source(paste(src.path, "Estimation", "basis_estimation.R", sep="/"))
source(paste(src.path, "Utility", "utility.R", sep="/"))
source(paste(src.path, "Estimation", "cca_estimation.R", sep="/"))
source(paste(src.path, "Utility", "R2python.R", sep="/"))
###specify save path and filename
# Out:
# Loading required package: spam
#
# Loading required package: dotCall64
#
# Loading required package: grid
#
# Spam version 2.7-0 (2021-06-25) is loaded.
# Type 'help( Spam)' or 'demo( spam)' for a short introduction
# and overview of this package.
# Help for individual functions is also obtained by adding the
# suffix '.spam' to the function name, e.g. 'help( chol.spam)'.
#
#
# Attaching package: 'spam'
#
#
# The following objects are masked from 'package:base':
#
#     backsolve, forwardsolve
#
#
# Loading required package: viridis
#
# Loading required package: viridisLite
#
#
# Try help(fields) to get started.
#
#
# Attaching package: 'Matrix'
#
#
# The following object is masked from 'package:spam':
#
#     det
#
#
# The following objects are masked from 'package:pracma':
#
#     expm, lu, tril, triu
#
#
# Loading required package: splines
#
# Loading required package: fds
#
# Loading required package: rainbow
#
# Loading required package: MASS
#
# Loading required package: pcaPP
#
# Loading required package: RCurl
#
# Loading required package: deSolve
#
#
# Attaching package: 'deSolve'
#
#
# The following object is masked from 'package:pracma':
#
#     rk4
#
#
#
# Attaching package: 'fda'
#
#
# The following object is masked from 'package:graphics':
#
#     matplot
#
#
#
# Attaching package: 'mvtnorm'
#
#
# The following object is masked from 'package:spam':
#
#     rmvnorm
#
#
# R.matlab v3.6.2 (2018-09-26) successfully loaded. See ?R.matlab for help.
#
#
# Attaching package: 'R.matlab'
#
#
# The following objects are masked from 'package:base':
#
#     getOption, isOpen

# %%
cov_name="tridiag3"

###specify parameters
n <- 200
PP <- 150
k.gen <- 9
M <- 2
obs.time <- seq(0,1,1/50)


gendata <- function(N, seed_id){
for (n in c(N)){
    for (p in c(PP)){
        ## be careful for the choice of the number of basis function 
## fourier basis: km must be odd
## bspline basis km>4
km.gen <- c(9,9)

Apinv_list <- list()
A_list <- list()
N_list <- list()
basis.m_list <- list()
true.basis_list <- list()
true.values_list <- list()




#generate data from the graph

if (cov_name == "tridiag1"){
    omega <- synth.omega.tridiag1_v2(p, k.gen)
}
if (cov_name == "tridiag2"){
    omega <- synth.omega.tridiag2_v2(p, k.gen)
}
if (cov_name == "tridiag3"){
    omega <- synth.omega.tridiag3_v2(p, k.gen)
}

#ensure that the diagonal values are all 1

G.true <- matrix(0, p, p) # p by p adjacency matrix
for(i in 1:p){
  for(j in 1:p){
    if(sum(abs(omega[((i-1)*k.gen+1):(i*k.gen), ((j-1)*k.gen+1):(j*k.gen)])) > 0)
      G.true[i,j] <- 1
  }
}

cov <- solve(omega)

for(m in 1:M){
    Am <- synth.linear_op.sparse_orthogonal(k.gen, km.gen[m], 3, scale=m*0.1)
    Am <- t(t(Am) %*% diag(.2*((1:k.gen))+1)) #this is to make the singular values distinct

    A_list[[m]] <- Am
    Apinv_list[[m]] <- solve(Am)
    #noise covariance
    N_list[[m]] <- diag(p*km.gen[m])*.001
    #structured noise
    basis.m_list[[m]] <- synth.fourier.bases.m(obs.time, km.gen[m])
}

#convert to regression B
B_list <- utility.graph2B(omega,p)
# save true graphs


#generate data 
#set.seed(seed_id)
#multivariate_data <- synth.dependent_data(n, p, cov, Apinv_list, N_list)
#set.seed(seed_id)
data <- synth.data_from_graph(n, p, cov, basis.m_list, Apinv_list,N_list, dependent=TRUE, addnoise=FALSE)

#########################
# test node aggragation #
#########################

concate_data <- list()
for(m in 1:2){
        dm <- data[[m]][,1,]
    for(i in 2:p){
        dm <- rbind(dm, data[[m]][,p,])
    }
    concate_data[[m]] <- dm
}
fourier.basis1 <- create.fourier.basis(rangeval=c(0,1), nbasis=km.gen[1])
d1 <-Data2fd(argvals=obs.time, y=t(concate_data[[1]]), basisobj=fourier.basis1)
#data modality 2
fourier.basis2 <- create.fourier.basis(rangeval=c(0,1), nbasis=km.gen[2])
d2 <-Data2fd(argvals=obs.time, y=t(concate_data[[2]]), basisobj=fourier.basis2)

cca.r.est <- estimate.cca.basis_expansion(d1, d2, km.gen[1])

##save data 
est_Ac <- list()
est_Ac[[1]] <- cca.r.est$A1
est_Ac[[2]] <- cca.r.est$A2 


######################
# test single node   #
######################


fourier.basis1 <- create.fourier.basis(rangeval=c(0,1), nbasis=km.gen[1])
d1 <-Data2fd(argvals=obs.time, y=t(data[[1]][,1,]), basisobj=fourier.basis1)
#data modality 2
fourier.basis2 <- create.fourier.basis(rangeval=c(0,1), nbasis=km.gen[2])
d2 <-Data2fd(argvals=obs.time, y=t(data[[2]][,1,]), basisobj=fourier.basis2)

cca.r.est <- estimate.cca.basis_expansion(d1, d2, km.gen[1])

##save data 
est_A <- list()
est_A[[1]] <- cca.r.est$A1
est_A[[2]] <- cca.r.est$A2 


#cca.r.est <- estimate.multivariate.cca(multivariate_data[[1]][,1:9], multivariate_data[[2]][,1:9],9)

#est_Am <- list()
#est_Am[[1]] <- cca.r.est$A1
#est_Am[[2]] <- cca.r.est$A2 

}
}
A <- list()
#A$est_Am <- est_Am
A$est_A  <- est_A
A$A_list <- A_list
A$est_Ac <- est_Ac
return(A)
}

# %%
diff_A_list <- list()
diff_Ac_list <- list()

for(iter in 1:10){
    diff_Am <- list()
    diff_A <- list()
    diff_Ac <- list()


    for(n in c(352, 391, 440, 503, 587, 705, 881, 1175, 1762, 3525, 17626)){
        A<-gendata(n, iter)

        A_list <- A$A_list
        est_Am <- A$est_Am
        est_A  <- A$est_A 
        est_Ac <- A$est_Ac
        for(i in 1:9){
            if(norm(est_A[[1]][i,]+A_list[[1]][i,]) < norm(est_A[[1]][i,]-A_list[[1]][i,])){
                est_A[[1]][i,] <- - est_A[[1]][i,] 
            }

        }

        for(i in 1:9){
            
            if(norm(est_A[[2]][i,]+A_list[[2]][i,]) < norm(est_A[[2]][i,]-A_list[[2]][i,])){
                est_A[[2]][i,] <- - est_A[[2]][i,] 
            }
        }

        for(i in 1:9){
            if(norm(est_Am[[1]][i,]+A_list[[1]][i,]) < norm(est_Am[[1]][i,]-A_list[[1]][i,])){
                est_Am[[1]][i,] <- - est_Am[[1]][i,] 
            }

        }

        for(i in 1:9){
            
        if(norm(est_Am[[2]][i,]+A_list[[2]][i,]) < norm(est_Am[[2]][i,]-A_list[[2]][i,])){
                est_Am[[2]][i,] <- - est_Am[[2]][i,] 
            }
        }

        for(i in 1:9){
            if(norm(est_Ac[[1]][i,]+A_list[[1]][i,]) < norm(est_Ac[[1]][i,]-A_list[[1]][i,])){
                est_Ac[[1]][i,] <- - est_Ac[[1]][i,] 
            }

        }

        for(i in 1:9){
            
            if(norm(est_Ac[[2]][i,]+A_list[[2]][i,]) < norm(est_Ac[[2]][i,]-A_list[[2]][i,])){
                est_Ac[[2]][i,] <- - est_Ac[[2]][i,] 
            }
        }

        tempA <- norm(est_A[[1]]-A_list[[1]])**2 + norm(est_A[[2]]-A_list[[2]])**2
        diff_A <- c(diff_A, tempA)

        tempAm <- norm(est_Am[[1]]-A_list[[1]])**2 + norm(est_Am[[2]]-A_list[[2]])**2
        diff_Am <- c(diff_Am, tempAm)


        tempAc <- norm(est_Ac[[1]]-A_list[[1]])**2 + norm(est_Ac[[2]]-A_list[[2]])**2
        diff_Ac <- c(diff_Ac, tempAc)

    }

    diff_A_list[[iter]] <- diff_A
    diff_Ac_list[[iter]] <- diff_Ac
}
# Out:
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999483 0.9999129 0.9998941 0.9998781 0.9998516 0.9997637 0.9997585
# [8] 0.9997027 0.9996976
# [1] "canonical correlation values:"
# [1] 0.9999372 0.9999253 0.9999080 0.9998531 0.9998374 0.9998007 0.9997770
# [8] 0.9997226 0.9995604
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999380 0.9999279 0.9998895 0.9998500 0.9998001 0.9997789 0.9997537
# [8] 0.9997170 0.9996385
# [1] "canonical correlation values:"
# [1] 0.9999453 0.9999232 0.9999092 0.9998689 0.9998591 0.9997853 0.9997559
# [8] 0.9996609 0.9995672
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999361 0.9999138 0.9998954 0.9998603 0.9998454 0.9997914 0.9997552
# [8] 0.9996762 0.9995508
# [1] "canonical correlation values:"
# [1] 0.9999401 0.9998995 0.9998805 0.9998525 0.9998311 0.9997947 0.9997590
# [8] 0.9997203 0.9996370
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999317 0.9999153 0.9998834 0.9998562 0.9998154 0.9997913 0.9997547
# [8] 0.9996751 0.9996358
# [1] "canonical correlation values:"
# [1] 0.9999432 0.9999113 0.9998971 0.9998791 0.9998203 0.9997991 0.9997100
# [8] 0.9996640 0.9996047
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999311 0.9999201 0.9998813 0.9998625 0.9998158 0.9997753 0.9997727
# [8] 0.9996550 0.9995532
# [1] "canonical correlation values:"
# [1] 0.9999338 0.9999276 0.9998735 0.9998541 0.9998432 0.9998082 0.9997577
# [8] 0.9996836 0.9996341
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999449 0.9999177 0.9998912 0.9998802 0.9998293 0.9997794 0.9997516
# [8] 0.9996697 0.9996167
# [1] "canonical correlation values:"
# [1] 0.9999439 0.9999201 0.9998944 0.9998504 0.9998367 0.9998022 0.9997607
# [8] 0.9996751 0.9996520
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999293 0.9999180 0.9998834 0.9998644 0.9998185 0.9997754 0.9997296
# [8] 0.9997087 0.9996345
# [1] "canonical correlation values:"
# [1] 0.9999317 0.9999158 0.9998786 0.9998660 0.9998127 0.9997847 0.9997424
# [8] 0.9996962 0.9996333
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999330 0.9999174 0.9998973 0.9998743 0.9998300 0.9997835 0.9997452
# [8] 0.9996996 0.9996281
# [1] "canonical correlation values:"
# [1] 0.9999375 0.9999144 0.9998903 0.9998511 0.9998165 0.9997848 0.9997583
# [8] 0.9996934 0.9996145
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999355 0.9999112 0.9998860 0.9998567 0.9998295 0.9998040 0.9997566
# [8] 0.9996815 0.9996250
# [1] "canonical correlation values:"
# [1] 0.9999367 0.9999138 0.9998828 0.9998559 0.9998247 0.9997867 0.9997429
# [8] 0.9997174 0.9996407
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999351 0.9999103 0.9998847 0.9998685 0.9998230 0.9997811 0.9997425
# [8] 0.9997010 0.9996185
# [1] "canonical correlation values:"
# [1] 0.9999379 0.9999151 0.9998943 0.9998630 0.9998307 0.9997836 0.9997491
# [8] 0.9996940 0.9996264
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999335 0.9999139 0.9998866 0.9998566 0.9998212 0.9997871 0.9997459
# [8] 0.9996924 0.9996241
# [1] "canonical correlation values:"
# [1] 0.9999374 0.9999100 0.9998855 0.9998574 0.9998219 0.9997864 0.9997416
# [8] 0.9996903 0.9996278
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999481 0.9999214 0.9999039 0.9998613 0.9998094 0.9997896 0.9997146
# [8] 0.9996515 0.9995525
# [1] "canonical correlation values:"
# [1] 0.9999421 0.9999135 0.9998879 0.9998762 0.9998270 0.9997581 0.9997379
# [8] 0.9996541 0.9996318
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999442 0.9999081 0.9998825 0.9998770 0.9998328 0.9997919 0.9997710
# [8] 0.9997469 0.9996794
# [1] "canonical correlation values:"
# [1] 0.9999354 0.9999170 0.9999025 0.9998746 0.9998285 0.9997787 0.9997440
# [8] 0.9996693 0.9996039
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999434 0.9999257 0.9998993 0.9998805 0.9998376 0.9997907 0.9997484
# [8] 0.9996618 0.9995672
# [1] "canonical correlation values:"
# [1] 0.9999436 0.9999147 0.9998984 0.9998635 0.9998453 0.9997890 0.9997202
# [8] 0.9996788 0.9996006
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999471 0.9999231 0.9998761 0.9998628 0.9997987 0.9997589 0.9997220
# [8] 0.9996635 0.9996440
# [1] "canonical correlation values:"
# [1] 0.9999325 0.9999108 0.9998983 0.9998430 0.9998176 0.9997704 0.9997631
# [8] 0.9997435 0.9995901
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999404 0.9999163 0.9999040 0.9998658 0.9998405 0.9997864 0.9997577
# [8] 0.9996991 0.9995965
# [1] "canonical correlation values:"
# [1] 0.9999374 0.9999121 0.9998782 0.9998581 0.9998080 0.9997938 0.9997435
# [8] 0.9996800 0.9996318
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999414 0.9999155 0.9998916 0.9998749 0.9998318 0.9997967 0.9997418
# [8] 0.9997076 0.9996009
# [1] "canonical correlation values:"
# [1] 0.9999398 0.9999312 0.9999004 0.9998702 0.9998408 0.9997989 0.9997398
# [8] 0.9996719 0.9996008
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999299 0.9999167 0.9998923 0.9998657 0.9998288 0.9997892 0.9997495
# [8] 0.9996780 0.9995654
# [1] "canonical correlation values:"
# [1] 0.9999406 0.9999213 0.9998874 0.9998611 0.9998160 0.9997962 0.9997365
# [8] 0.9996535 0.9996341
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999377 0.9999200 0.9998963 0.9998616 0.9998251 0.9997780 0.9997612
# [8] 0.9997112 0.9996297
# [1] "canonical correlation values:"
# [1] 0.9999406 0.9999187 0.9998899 0.9998531 0.9998179 0.9997804 0.9997589
# [8] 0.9996868 0.9996320
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999377 0.9999117 0.9998907 0.9998479 0.9998249 0.9997873 0.9997484
# [8] 0.9996654 0.9996156
# [1] "canonical correlation values:"
# [1] 0.9999267 0.9999148 0.9998866 0.9998452 0.9998257 0.9997978 0.9997418
# [8] 0.9996983 0.9995892
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999346 0.9999131 0.9998891 0.9998542 0.9998184 0.9997722 0.9997397
# [8] 0.9996970 0.9996164
# [1] "canonical correlation values:"
# [1] 0.9999373 0.9999175 0.9998827 0.9998553 0.9998129 0.9997977 0.9997459
# [8] 0.9996992 0.9996373
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999354 0.9999107 0.9998873 0.9998584 0.9998243 0.9997823 0.9997480
# [8] 0.9996993 0.9996301
# [1] "canonical correlation values:"
# [1] 0.9999352 0.9999109 0.9998855 0.9998563 0.9998231 0.9997802 0.9997521
# [8] 0.9996968 0.9996357
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999316 0.9999235 0.9998962 0.9998500 0.9998342 0.9997954 0.9997248
# [8] 0.9997037 0.9996226
# [1] "canonical correlation values:"
# [1] 0.9999376 0.9999240 0.9998763 0.9998724 0.9998165 0.9997931 0.9997758
# [8] 0.9996510 0.9996051
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999348 0.9999200 0.9999018 0.9998543 0.9998322 0.9997773 0.9997536
# [8] 0.9997079 0.9996406
# [1] "canonical correlation values:"
# [1] 0.9999311 0.9999277 0.9998891 0.9998658 0.9998328 0.9998029 0.9997455
# [8] 0.9997101 0.9996297
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999415 0.9999168 0.9999031 0.9998649 0.9998496 0.9997968 0.9997516
# [8] 0.9996933 0.9995958
# [1] "canonical correlation values:"
# [1] 0.9999486 0.9999196 0.9998904 0.9998738 0.9998154 0.9997841 0.9997270
# [8] 0.9996816 0.9995775
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999351 0.9999213 0.9998858 0.9998601 0.9998344 0.9997892 0.9997246
# [8] 0.9996816 0.9996028
# [1] "canonical correlation values:"
# [1] 0.9999505 0.9999195 0.9998945 0.9998616 0.9998087 0.9997734 0.9997450
# [8] 0.9996696 0.9995829
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999463 0.9999211 0.9998993 0.9998497 0.9998359 0.9997959 0.9997326
# [8] 0.9996739 0.9996309
# [1] "canonical correlation values:"
# [1] 0.9999400 0.9999178 0.9999039 0.9998636 0.9998099 0.9997757 0.9997493
# [8] 0.9996905 0.9996383
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999415 0.9999235 0.9998869 0.9998663 0.9998143 0.9997789 0.9997533
# [8] 0.9997266 0.9996267
# [1] "canonical correlation values:"
# [1] 0.9999391 0.9999235 0.9999038 0.9998522 0.9998295 0.9997921 0.9997409
# [8] 0.9997192 0.9996280
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999342 0.9999195 0.9998758 0.9998409 0.9998399 0.9998166 0.9997489
# [8] 0.9997115 0.9996168
# [1] "canonical correlation values:"
# [1] 0.9999372 0.9999107 0.9998880 0.9998508 0.9998180 0.9997560 0.9997166
# [8] 0.9996879 0.9996377
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999388 0.9999131 0.9998868 0.9998542 0.9998241 0.9997629 0.9997548
# [8] 0.9996785 0.9996282
# [1] "canonical correlation values:"
# [1] 0.9999374 0.9999199 0.9998944 0.9998638 0.9998206 0.9997643 0.9997422
# [8] 0.9996990 0.9996502
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999371 0.9999169 0.9998931 0.9998647 0.9998361 0.9997884 0.9997247
# [8] 0.9996864 0.9996336
# [1] "canonical correlation values:"
# [1] 0.9999358 0.9999103 0.9998982 0.9998561 0.9998205 0.9998056 0.9997552
# [8] 0.9996937 0.9996122
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999364 0.9999157 0.9998833 0.9998577 0.9998252 0.9997813 0.9997426
# [8] 0.9996801 0.9996216
# [1] "canonical correlation values:"
# [1] 0.9999406 0.9999112 0.9998918 0.9998503 0.9998261 0.9997888 0.9997364
# [8] 0.9996961 0.9996358
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999370 0.9999125 0.9998837 0.9998554 0.9998208 0.9997910 0.9997466
# [8] 0.9996996 0.9996359
# [1] "canonical correlation values:"
# [1] 0.9999377 0.9999118 0.9998863 0.9998551 0.9998293 0.9997864 0.9997465
# [8] 0.9996991 0.9996410
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999441 0.9999219 0.9998804 0.9998461 0.9998163 0.9998062 0.9997571
# [8] 0.9997153 0.9996333
# [1] "canonical correlation values:"
# [1] 0.9999444 0.9998992 0.9998906 0.9998714 0.9998110 0.9997689 0.9997520
# [8] 0.9996874 0.9996608
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999353 0.9999205 0.9998880 0.9998552 0.9998229 0.9997979 0.9997804
# [8] 0.9996314 0.9995874
# [1] "canonical correlation values:"
# [1] 0.9999337 0.9999255 0.9998833 0.9998684 0.9998294 0.9997970 0.9997522
# [8] 0.9996604 0.9996306
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999425 0.9999210 0.9998911 0.9998671 0.9998268 0.9997554 0.9997325
# [8] 0.9996855 0.9995891
# [1] "canonical correlation values:"
# [1] 0.9999485 0.9999270 0.9998913 0.9998695 0.9998235 0.9998127 0.9997843
# [8] 0.9997411 0.9996629
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999411 0.9999227 0.9998939 0.9998575 0.9998334 0.9997630 0.9997331
# [8] 0.9996838 0.9995997
# [1] "canonical correlation values:"
# [1] 0.9999412 0.9999153 0.9998766 0.9998557 0.9998221 0.9997642 0.9997330
# [8] 0.9996949 0.9996473
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999425 0.9999175 0.9999062 0.9998698 0.9998290 0.9998040 0.9997664
# [8] 0.9996661 0.9996114
# [1] "canonical correlation values:"
# [1] 0.9999406 0.9999177 0.9998993 0.9998524 0.9998298 0.9998126 0.9997396
# [8] 0.9996935 0.9996572
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999331 0.9999172 0.9998948 0.9998531 0.9998270 0.9997646 0.9997228
# [8] 0.9996997 0.9996255
# [1] "canonical correlation values:"
# [1] 0.9999458 0.9999213 0.9999035 0.9998616 0.9998346 0.9998005 0.9997301
# [8] 0.9996841 0.9996424
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999421 0.9999165 0.9998957 0.9998406 0.9998146 0.9998021 0.9997042
# [8] 0.9996815 0.9996060
# [1] "canonical correlation values:"
# [1] 0.9999311 0.9999065 0.9998962 0.9998609 0.9998254 0.9997897 0.9997421
# [8] 0.9996792 0.9996048
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999461 0.9999143 0.9998862 0.9998564 0.9998189 0.9997970 0.9997605
# [8] 0.9996958 0.9996244
# [1] "canonical correlation values:"
# [1] 0.9999421 0.9999135 0.9998939 0.9998611 0.9998173 0.9997833 0.9997254
# [8] 0.9996609 0.9996391
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999370 0.9999110 0.9998875 0.9998389 0.9998175 0.9997894 0.9997277
# [8] 0.9997092 0.9996054
# [1] "canonical correlation values:"
# [1] 0.9999381 0.9999157 0.9998923 0.9998605 0.9998191 0.9997758 0.9997255
# [8] 0.9996756 0.9996484
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999386 0.9999158 0.9998873 0.9998610 0.9998291 0.9997836 0.9997551
# [8] 0.9996973 0.9996419
# [1] "canonical correlation values:"
# [1] 0.9999366 0.9999122 0.9998856 0.9998603 0.9998196 0.9997856 0.9997401
# [8] 0.9996957 0.9996200
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999368 0.9999137 0.9998894 0.9998546 0.9998264 0.9997905 0.9997440
# [8] 0.9996915 0.9996346
# [1] "canonical correlation values:"
# [1] 0.9999358 0.9999128 0.9998866 0.9998567 0.9998225 0.9997853 0.9997472
# [8] 0.9996956 0.9996387
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999413 0.9999100 0.9999048 0.9998544 0.9998412 0.9997989 0.9997898
# [8] 0.9996900 0.9995744
# [1] "canonical correlation values:"
# [1] 0.9999440 0.9999299 0.9999068 0.9998720 0.9998491 0.9997952 0.9997579
# [8] 0.9997470 0.9995582
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999412 0.9999172 0.9998847 0.9998507 0.9998360 0.9998061 0.9997490
# [8] 0.9997184 0.9995874
# [1] "canonical correlation values:"
# [1] 0.9999443 0.9999178 0.9998926 0.9998811 0.9998345 0.9997779 0.9997348
# [8] 0.9996473 0.9996433
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999453 0.9999032 0.9998702 0.9998621 0.9998128 0.9997621 0.9997252
# [8] 0.9996634 0.9995793
# [1] "canonical correlation values:"
# [1] 0.9999451 0.9999239 0.9998879 0.9998814 0.9998194 0.9997837 0.9997681
# [8] 0.9996810 0.9996403
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999447 0.9999198 0.9998934 0.9998699 0.9998142 0.9997874 0.9997319
# [8] 0.9996989 0.9995540
# [1] "canonical correlation values:"
# [1] 0.9999392 0.9999144 0.9998924 0.9998694 0.9998292 0.9998042 0.9997462
# [8] 0.9997138 0.9995633
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999445 0.9999241 0.9998908 0.9998714 0.9998461 0.9998112 0.9997412
# [8] 0.9997044 0.9996873
# [1] "canonical correlation values:"
# [1] 0.9999434 0.9999247 0.9998763 0.9998542 0.9998342 0.9997996 0.9997650
# [8] 0.9997218 0.9996396
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999349 0.9999153 0.9998929 0.9998472 0.9998273 0.9997977 0.9997402
# [8] 0.9996846 0.9996389
# [1] "canonical correlation values:"
# [1] 0.9999331 0.9999134 0.9998848 0.9998592 0.9998329 0.9998112 0.9997347
# [8] 0.9997288 0.9996030
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999445 0.9999133 0.9998883 0.9998517 0.9998137 0.9998015 0.9997318
# [8] 0.9996920 0.9996107
# [1] "canonical correlation values:"
# [1] 0.9999411 0.9999240 0.9999016 0.9998820 0.9998253 0.9997859 0.9997229
# [8] 0.9997032 0.9996072
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999367 0.9999167 0.9998955 0.9998681 0.9998225 0.9997972 0.9997504
# [8] 0.9996751 0.9996371
# [1] "canonical correlation values:"
# [1] 0.9999414 0.9999152 0.9998872 0.9998585 0.9998344 0.9997985 0.9997683
# [8] 0.9997027 0.9996480
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999346 0.9999107 0.9998883 0.9998487 0.9998195 0.9997703 0.9997529
# [8] 0.9997114 0.9996064
# [1] "canonical correlation values:"
# [1] 0.9999356 0.9999122 0.9998827 0.9998599 0.9998252 0.9997698 0.9997356
# [8] 0.9997060 0.9996192
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999369 0.9999160 0.9998903 0.9998454 0.9998242 0.9997728 0.9997407
# [8] 0.9997011 0.9996394
# [1] "canonical correlation values:"
# [1] 0.9999363 0.9999143 0.9998855 0.9998572 0.9998294 0.9997813 0.9997550
# [8] 0.9996994 0.9996272
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999368 0.9999140 0.9998871 0.9998514 0.9998195 0.9997823 0.9997440
# [8] 0.9996966 0.9996306
# [1] "canonical correlation values:"
# [1] 0.9999366 0.9999121 0.9998893 0.9998514 0.9998216 0.9997811 0.9997395
# [8] 0.9996913 0.9996352
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999427 0.9999223 0.9999009 0.9998738 0.9998576 0.9997937 0.9997292
# [8] 0.9996891 0.9996279
# [1] "canonical correlation values:"
# [1] 0.9999418 0.9999086 0.9999057 0.9998564 0.9998030 0.9997466 0.9997408
# [8] 0.9997008 0.9996266
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999396 0.9999117 0.9998982 0.9998621 0.9998060 0.9997977 0.9997516
# [8] 0.9996704 0.9996053
# [1] "canonical correlation values:"
# [1] 0.9999389 0.9999158 0.9999012 0.9998807 0.9998311 0.9997905 0.9997687
# [8] 0.9997393 0.9996539
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999407 0.9999267 0.9998940 0.9998663 0.9998587 0.9997946 0.9997552
# [8] 0.9996641 0.9996022
# [1] "canonical correlation values:"
# [1] 0.9999420 0.9999220 0.9999047 0.9998483 0.9998311 0.9997824 0.9997557
# [8] 0.9997341 0.9996681
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999401 0.9999194 0.9998852 0.9998631 0.9998287 0.9997966 0.9997652
# [8] 0.9996751 0.9996340
# [1] "canonical correlation values:"
# [1] 0.9999326 0.9999170 0.9998876 0.9998511 0.9998261 0.9997783 0.9997390
# [8] 0.9996918 0.9996618
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999346 0.9999189 0.9998823 0.9998656 0.9998289 0.9998054 0.9997420
# [8] 0.9997068 0.9996464
# [1] "canonical correlation values:"
# [1] 0.9999412 0.9999203 0.9998978 0.9998607 0.9998196 0.9997932 0.9997567
# [8] 0.9996672 0.9996128
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999318 0.9999223 0.9998945 0.9998601 0.9998036 0.9997784 0.9997343
# [8] 0.9996694 0.9995783
# [1] "canonical correlation values:"
# [1] 0.9999443 0.9999143 0.9999016 0.9998529 0.9998057 0.9997995 0.9997460
# [8] 0.9996940 0.9996082
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999405 0.9999243 0.9998783 0.9998629 0.9998248 0.9997747 0.9997556
# [8] 0.9996507 0.9995970
# [1] "canonical correlation values:"
# [1] 0.9999412 0.9999178 0.9998863 0.9998606 0.9998392 0.9997638 0.9997213
# [8] 0.9996854 0.9996436
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999402 0.9999131 0.9998852 0.9998579 0.9998173 0.9997902 0.9997476
# [8] 0.9996879 0.9996249
# [1] "canonical correlation values:"
# [1] 0.9999324 0.9999163 0.9998864 0.9998640 0.9998386 0.9997915 0.9997432
# [8] 0.9997172 0.9996268
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999379 0.9999160 0.9998794 0.9998626 0.9998197 0.9997848 0.9997420
# [8] 0.9996881 0.9996319
# [1] "canonical correlation values:"
# [1] 0.9999320 0.9999105 0.9998820 0.9998737 0.9998328 0.9997787 0.9997636
# [8] 0.9996877 0.9996292
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999372 0.9999148 0.9998876 0.9998711 0.9998289 0.9997862 0.9997308
# [8] 0.9996950 0.9996265
# [1] "canonical correlation values:"
# [1] 0.9999393 0.9999143 0.9998904 0.9998648 0.9998219 0.9997726 0.9997341
# [8] 0.9997096 0.9996368
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999345 0.9999153 0.9998873 0.9998564 0.9998247 0.9997806 0.9997438
# [8] 0.9996951 0.9996293
# [1] "canonical correlation values:"
# [1] 0.9999361 0.9999141 0.9998881 0.9998563 0.9998178 0.9997780 0.9997305
# [8] 0.9997004 0.9996268
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999389 0.9999236 0.9998954 0.9998786 0.9998424 0.9998013 0.9997015
# [8] 0.9996822 0.9996213
# [1] "canonical correlation values:"
# [1] 0.9999561 0.9999154 0.9998777 0.9998747 0.9998463 0.9997645 0.9997495
# [8] 0.9996807 0.9996204
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999341 0.9999232 0.9999019 0.9998594 0.9998181 0.9997918 0.9997478
# [8] 0.9996635 0.9995724
# [1] "canonical correlation values:"
# [1] 0.9999356 0.9999202 0.9999054 0.9998441 0.9998234 0.9997965 0.9997301
# [8] 0.9997028 0.9995153
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999351 0.9999052 0.9998903 0.9998685 0.9998124 0.9997862 0.9997538
# [8] 0.9996580 0.9995443
# [1] "canonical correlation values:"
# [1] 0.9999425 0.9999120 0.9998869 0.9998665 0.9998335 0.9997928 0.9997650
# [8] 0.9997082 0.9995849
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999471 0.9999266 0.9998992 0.9998671 0.9998385 0.9997920 0.9997580
# [8] 0.9996929 0.9996062
# [1] "canonical correlation values:"
# [1] 0.9999500 0.9999208 0.9998981 0.9998582 0.9998255 0.9997960 0.9997688
# [8] 0.9997255 0.9996575
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999378 0.9999191 0.9998737 0.9998698 0.9998417 0.9998013 0.9997271
# [8] 0.9996439 0.9996403
# [1] "canonical correlation values:"
# [1] 0.9999424 0.9999282 0.9998985 0.9998849 0.9998358 0.9998112 0.9997290
# [8] 0.9996716 0.9996459
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999410 0.9999090 0.9998858 0.9998450 0.9998264 0.9997682 0.9997160
# [8] 0.9996846 0.9996384
# [1] "canonical correlation values:"
# [1] 0.9999428 0.9999217 0.9999005 0.9998472 0.9998395 0.9997675 0.9997359
# [8] 0.9996915 0.9995895
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999344 0.9999168 0.9998818 0.9998546 0.9998078 0.9997646 0.9997331
# [8] 0.9996966 0.9996214
# [1] "canonical correlation values:"
# [1] 0.9999421 0.9999136 0.9998893 0.9998544 0.9998370 0.9998071 0.9997446
# [8] 0.9996905 0.9996091
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999373 0.9999132 0.9998858 0.9998534 0.9998251 0.9998082 0.9997303
# [8] 0.9996967 0.9996159
# [1] "canonical correlation values:"
# [1] 0.9999328 0.9999246 0.9998840 0.9998606 0.9998366 0.9997997 0.9997344
# [8] 0.9997084 0.9995947
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999389 0.9999149 0.9998845 0.9998600 0.9998165 0.9997714 0.9997418
# [8] 0.9996777 0.9996437
# [1] "canonical correlation values:"
# [1] 0.9999386 0.9999237 0.9998837 0.9998626 0.9998303 0.9997820 0.9997406
# [8] 0.9996965 0.9996314
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999339 0.9999150 0.9998901 0.9998572 0.9998123 0.9997793 0.9997406
# [8] 0.9996912 0.9996257
# [1] "canonical correlation values:"
# [1] 0.9999309 0.9999148 0.9998928 0.9998522 0.9998213 0.9997882 0.9997384
# [8] 0.9996881 0.9996358
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999344 0.9999147 0.9998856 0.9998548 0.9998183 0.9997851 0.9997471
# [8] 0.9996981 0.9996305
# [1] "canonical correlation values:"
# [1] 0.9999367 0.9999146 0.9998851 0.9998551 0.9998200 0.9997865 0.9997449
# [8] 0.9996934 0.9996357
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999448 0.9999097 0.9998869 0.9998703 0.9998246 0.9997829 0.9997311
# [8] 0.9997091 0.9996000
# [1] "canonical correlation values:"
# [1] 0.9999382 0.9999183 0.9998789 0.9998698 0.9998301 0.9997895 0.9997436
# [8] 0.9997062 0.9996259
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999373 0.9999141 0.9999037 0.9998615 0.9998454 0.9998185 0.9997098
# [8] 0.9996911 0.9996028
# [1] "canonical correlation values:"
# [1] 0.9999457 0.9999212 0.9999022 0.9998803 0.9998195 0.9997695 0.9997500
# [8] 0.9997107 0.9996421
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999282 0.9999108 0.9998743 0.9998657 0.9998345 0.9997549 0.9997315
# [8] 0.9996856 0.9996038
# [1] "canonical correlation values:"
# [1] 0.9999456 0.9999100 0.9998817 0.9998705 0.9998468 0.9997675 0.9997595
# [8] 0.9996453 0.9995383
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999418 0.9999263 0.9999013 0.9998577 0.9998402 0.9997838 0.9997473
# [8] 0.9996753 0.9996234
# [1] "canonical correlation values:"
# [1] 0.9999325 0.9999111 0.9998889 0.9998804 0.9998360 0.9997715 0.9997234
# [8] 0.9996715 0.9994805
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999359 0.9999208 0.9998844 0.9998453 0.9998280 0.9997945 0.9997497
# [8] 0.9997211 0.9996025
# [1] "canonical correlation values:"
# [1] 0.9999355 0.9999151 0.9998893 0.9998701 0.9998164 0.9998129 0.9997554
# [8] 0.9996825 0.9995878
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999361 0.9999156 0.9998904 0.9998536 0.9998346 0.9997927 0.9997394
# [8] 0.9996793 0.9996299
# [1] "canonical correlation values:"
# [1] 0.9999448 0.9999092 0.9998908 0.9998525 0.9998292 0.9998015 0.9997436
# [8] 0.9996831 0.9996395
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999360 0.9999093 0.9998960 0.9998609 0.9998396 0.9998092 0.9997320
# [8] 0.9996868 0.9996305
# [1] "canonical correlation values:"
# [1] 0.9999355 0.9999195 0.9998779 0.9998751 0.9998376 0.9997494 0.9997343
# [8] 0.9997220 0.9995975
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999359 0.9999162 0.9998999 0.9998673 0.9998189 0.9997898 0.9997620
# [8] 0.9996778 0.9995980
# [1] "canonical correlation values:"
# [1] 0.9999467 0.9999117 0.9998858 0.9998697 0.9998107 0.9997773 0.9997396
# [8] 0.9996652 0.9996539
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999355 0.9999136 0.9998875 0.9998482 0.9998247 0.9997870 0.9997476
# [8] 0.9997087 0.9996119
# [1] "canonical correlation values:"
# [1] 0.9999318 0.9999158 0.9998934 0.9998511 0.9998334 0.9997982 0.9997445
# [8] 0.9997176 0.9996196
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999358 0.9999154 0.9998876 0.9998541 0.9998210 0.9997900 0.9997410
# [8] 0.9996772 0.9996404
# [1] "canonical correlation values:"
# [1] 0.9999338 0.9999160 0.9998860 0.9998613 0.9998123 0.9997859 0.9997326
# [8] 0.9997007 0.9996137
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999371 0.9999148 0.9998867 0.9998562 0.9998216 0.9997862 0.9997440
# [8] 0.9996865 0.9996312
# [1] "canonical correlation values:"
# [1] 0.9999359 0.9999107 0.9998848 0.9998546 0.9998225 0.9997847 0.9997482
# [8] 0.9996929 0.9996334
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999292 0.9999220 0.9998917 0.9998863 0.9998337 0.9998023 0.9997621
# [8] 0.9996808 0.9995990
# [1] "canonical correlation values:"
# [1] 0.9999486 0.9999146 0.9999000 0.9998782 0.9998406 0.9997524 0.9997289
# [8] 0.9996565 0.9995752
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999515 0.9999119 0.9998986 0.9998627 0.9998151 0.9997495 0.9997244
# [8] 0.9996903 0.9996312
# [1] "canonical correlation values:"
# [1] 0.9999375 0.9999092 0.9999015 0.9998826 0.9998098 0.9997845 0.9997667
# [8] 0.9996641 0.9996307
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999477 0.9999266 0.9998833 0.9998626 0.9998461 0.9997946 0.9997413
# [8] 0.9997080 0.9996191
# [1] "canonical correlation values:"
# [1] 0.9999449 0.9999042 0.9998864 0.9998371 0.9998348 0.9998051 0.9997448
# [8] 0.9997128 0.9996275
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999336 0.9999195 0.9998844 0.9998699 0.9998161 0.9998103 0.9997447
# [8] 0.9997043 0.9996030
# [1] "canonical correlation values:"
# [1] 0.9999360 0.9999188 0.9998899 0.9998582 0.9998216 0.9997824 0.9997390
# [8] 0.9996617 0.9996319
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999440 0.9999143 0.9998864 0.9998591 0.9998449 0.9997630 0.9997334
# [8] 0.9996849 0.9995676
# [1] "canonical correlation values:"
# [1] 0.9999474 0.9999101 0.9998881 0.9998483 0.9998343 0.9997521 0.9997425
# [8] 0.9997001 0.9996258
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999466 0.9999210 0.9998899 0.9998587 0.9998367 0.9997879 0.9997307
# [8] 0.9996590 0.9995952
# [1] "canonical correlation values:"
# [1] 0.9999389 0.9999158 0.9998750 0.9998457 0.9998316 0.9997833 0.9997568
# [8] 0.9996500 0.9995844
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999438 0.9999136 0.9998947 0.9998642 0.9998265 0.9997837 0.9997663
# [8] 0.9996765 0.9996231
# [1] "canonical correlation values:"
# [1] 0.9999410 0.9999214 0.9998890 0.9998633 0.9998350 0.9997985 0.9997581
# [8] 0.9996849 0.9996423
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999415 0.9999177 0.9998815 0.9998634 0.9998120 0.9997827 0.9997427
# [8] 0.9997007 0.9996167
# [1] "canonical correlation values:"
# [1] 0.9999319 0.9999103 0.9998870 0.9998480 0.9998181 0.9998012 0.9997458
# [8] 0.9996635 0.9996419
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999335 0.9999181 0.9998790 0.9998658 0.9998192 0.9998026 0.9997488
# [8] 0.9997075 0.9996505
# [1] "canonical correlation values:"
# [1] 0.9999357 0.9999126 0.9998837 0.9998632 0.9998124 0.9997887 0.9997522
# [8] 0.9997072 0.9996438
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999345 0.9999099 0.9998914 0.9998519 0.9998208 0.9997852 0.9997341
# [8] 0.9997033 0.9996527
# [1] "canonical correlation values:"
# [1] 0.9999369 0.9999094 0.9998950 0.9998634 0.9998187 0.9997821 0.9997386
# [8] 0.9996969 0.9996297
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999359 0.9999123 0.9998848 0.9998535 0.9998260 0.9997876 0.9997477
# [8] 0.9996948 0.9996254
# [1] "canonical correlation values:"
# [1] 0.9999355 0.9999138 0.9998885 0.9998534 0.9998229 0.9997895 0.9997438
# [8] 0.9996955 0.9996396
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999300 0.9999170 0.9998947 0.9998671 0.9998311 0.9997553 0.9997204
# [8] 0.9996450 0.9995671
# [1] "canonical correlation values:"
# [1] 0.9999446 0.9999308 0.9999135 0.9998486 0.9998370 0.9997938 0.9997735
# [8] 0.9997093 0.9995782
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999450 0.9999118 0.9998966 0.9998635 0.9998340 0.9998128 0.9997740
# [8] 0.9997185 0.9996357
# [1] "canonical correlation values:"
# [1] 0.9999377 0.9999190 0.9998945 0.9998694 0.9998203 0.9998193 0.9997313
# [8] 0.9996760 0.9996004
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999402 0.9999153 0.9998751 0.9998694 0.9998341 0.9997859 0.9997345
# [8] 0.9996774 0.9996291
# [1] "canonical correlation values:"
# [1] 0.9999409 0.9999112 0.9998856 0.9998735 0.9998513 0.9997955 0.9997658
# [8] 0.9996952 0.9995839
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999362 0.9999109 0.9998843 0.9998676 0.9998178 0.9997937 0.9997391
# [8] 0.9997103 0.9996149
# [1] "canonical correlation values:"
# [1] 0.9999374 0.9999179 0.9998928 0.9998488 0.9998216 0.9997830 0.9997606
# [8] 0.9996753 0.9995399
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999397 0.9999239 0.9999079 0.9998540 0.9998264 0.9997987 0.9997495
# [8] 0.9996646 0.9996039
# [1] "canonical correlation values:"
# [1] 0.9999345 0.9999237 0.9999002 0.9998821 0.9998225 0.9998041 0.9997193
# [8] 0.9996919 0.9995722
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999309 0.9999221 0.9998987 0.9998322 0.9998055 0.9997943 0.9997505
# [8] 0.9997149 0.9996081
# [1] "canonical correlation values:"
# [1] 0.9999262 0.9999107 0.9998892 0.9998537 0.9998215 0.9997859 0.9997501
# [8] 0.9996937 0.9996345
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999417 0.9999154 0.9998942 0.9998593 0.9998285 0.9997821 0.9997498
# [8] 0.9996737 0.9995937
# [1] "canonical correlation values:"
# [1] 0.9999426 0.9999260 0.9998999 0.9998479 0.9998338 0.9997963 0.9997599
# [8] 0.9996971 0.9995958
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999426 0.9999192 0.9998912 0.9998565 0.9998268 0.9997932 0.9997512
# [8] 0.9997154 0.9995734
# [1] "canonical correlation values:"
# [1] 0.9999371 0.9999049 0.9998870 0.9998575 0.9998202 0.9997729 0.9997407
# [8] 0.9996796 0.9996321
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999403 0.9999129 0.9998842 0.9998636 0.9998210 0.9997893 0.9997304
# [8] 0.9996795 0.9996160
# [1] "canonical correlation values:"
# [1] 0.9999396 0.9999109 0.9998843 0.9998589 0.9998200 0.9997976 0.9997431
# [8] 0.9996902 0.9996100
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999385 0.9999140 0.9998882 0.9998566 0.9998275 0.9997900 0.9997599
# [8] 0.9996935 0.9996292
# [1] "canonical correlation values:"
# [1] 0.9999344 0.9999191 0.9998803 0.9998574 0.9998327 0.9997913 0.9997418
# [8] 0.9996819 0.9996305
# [1] "Generating data from modality 1"
# [1] "Generating data from modality 2"
# [1] "canonical correlation values:"
# [1] 0.9999366 0.9999134 0.9998845 0.9998539 0.9998236 0.9997834 0.9997448
# [8] 0.9997019 0.9996351
# [1] "canonical correlation values:"
# [1] 0.9999363 0.9999146 0.9998887 0.9998520 0.9998240 0.9997834 0.9997421
# [8] 0.9996872 0.9996342

# %%
remove_outlier <- function(data_list, a = 2){
    data.mean <- mean(unlist(data_list))
    data.std  <- std(unlist(data_list))
    return.list <- list()
    for(data in data_list){
        if(data <= data.mean + a*data.std){
            if(data >= data.mean - a*data.std){
                return.list <- append(return.list, data)
            }
        }
        
    }
    return(return.list)
}

# %%
Nlist = c(352, 391, 440, 503, 587, 705, 881, 1175, 1762, 3525, 17626)
for(n in 1:11){
    Alist <- list()
    for(iter in 1:10){
        A_list[[iter]] <- diff_Ac_list[[iter]][n]
    }
    print(paste('n=', Nlist[n]," ", mean(unlist(A_list)), '(',std(unlist(A_list)), ')', sep=""))
    A_list_rm <- remove_outlier(A_list)

    
}

print('remove outlier')
for(n in 1:11){
    Alist <- list()
    for(iter in 1:10){
        A_list[[iter]] <- diff_Ac_list[[iter]][n]
    }

    A_list_rm <- remove_outlier(A_list)
    
    print(paste('n=', Nlist[n], " ", mean(unlist(A_list_rm)), '(',std(unlist(A_list_rm)), ')', sep=""))
    
}
# Out:
# [1] "n=352 1.40601014736238(0.546455776514321)"
# [1] "n=391 1.28397819752615(0.56147915999103)"
# [1] "n=440 1.16344717171908(0.249424759076036)"
# [1] "n=503 1.62954523282343(0.788122775910645)"
# [1] "n=587 1.2689322453012(0.59955606864558)"
# [1] "n=705 1.21213359675747(0.854968665144999)"
# [1] "n=881 0.833694562516734(0.269887060074659)"
# [1] "n=1175 0.762351866538836(0.192597668206116)"
# [1] "n=1762 0.639860920868559(0.269008738042895)"
# [1] "n=3525 0.538849608472021(0.14771688088566)"
# [1] "n=17626 0.519059664126836(0.103997852371649)"
# [1] "remove outlier"
# [1] "n=352 1.40601014736238(0.546455776514321)"
# [1] "n=391 1.28397819752615(0.56147915999103)"
# [1] "n=440 1.16344717171908(0.249424759076036)"
# [1] "n=503 1.44951347420037(0.578058011688677)"
# [1] "n=587 1.12228293844347(0.403061035527002)"
# [1] "n=705 0.953746825787037(0.266928749456391)"
# [1] "n=881 0.833694562516734(0.269887060074659)"
# [1] "n=1175 0.762351866538836(0.192597668206116)"
# [1] "n=1762 0.576640703286918(0.190912178204593)"
# [1] "n=3525 0.538849608472021(0.14771688088566)"
# [1] "n=17626 0.519059664126836(0.103997852371649)"

# %%
for(n in 1:11){
    Alist <- list()
    for(iter in 1:10){
        A_list[[iter]] <- diff_A_list[[iter]][n]
    }
    print(paste(mean(unlist(A_list)), std(unlist(A_list))))

}


print('remove outlier')
for(n in 1:11){
    Alist <- list()
    for(iter in 1:10){
        A_list[[iter]] <- diff_A_list[[iter]][n]
    }

    A_list_rm <- remove_outlier(A_list)
    
    print(paste(mean(unlist(A_list_rm)), std(unlist(A_list_rm))))
    
}
# Out:
# [1] "1.3091072646587 0.777910605245543"
# [1] "1.36039057733118 0.329127221509846"
# [1] "1.2227273529219 0.432402340261286"
# [1] "1.15795684646271 0.443674364539738"
# [1] "0.993673173614625 0.362240496273784"
# [1] "1.03988459734306 0.28983132085036"
# [1] "1.01140839307437 0.341473104266605"
# [1] "0.792886077887757 0.248742405038068"
# [1] "0.61092575654259 0.244165891699361"
# [1] "0.590602285716118 0.226684622245258"
# [1] "0.499299085155006 0.0816936876994606"
# [1] "remove outlier"
# [1] "1.11753509348592 0.517604274358638"
# [1] "1.36039057733118 0.329127221509846"
# [1] "1.2227273529219 0.432402340261286"
# [1] "1.15795684646271 0.443674364539738"
# [1] "0.993673173614625 0.362240496273784"
# [1] "1.03988459734306 0.28983132085036"
# [1] "1.01140839307437 0.341473104266605"
# [1] "0.736466789838866 0.183838519774203"
# [1] "0.61092575654259 0.244165891699361"
# [1] "0.590602285716118 0.226684622245258"
# [1] "0.480063789485365 0.0578414141582017"
